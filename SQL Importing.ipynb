# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="wolvesaywe123",
    database='sales elverys')

# %%
mycursor = mydb.cursor()
mycursor.execute('SELECT * FROM `sales elverys`.online_sales_report')
myresults = mycursor.fetchall()
myresults
# Out:
# [('FOOTWEAR_WOMEN',
#   'WOMEN_PERF_FW',
#   'LDSRUNFW',
#   1122863,
#   '22Q1',
#   'Brooks Adrenaline GTS 22 Wmn Fw Blk/Purp',
#   147,
#   16,
#   '10.88%',
#   '21,545',
#   '49.60%',
#   529,
#   91,
#   3.6,
#   0.62),
#  ('KEEPFIT',
#   'KPF_MACHINE',
#   'KPFTTREAD',
#   1090345,
#   '21/22',
#   'ProForm 525i Treadmill Black',
#   24,
#   22,
#   '91.67%',
#   '17,474',
#   '21.90%',
#   114,
#   100,
#   4.75,
#   4.17),
#  ('FOOTWEAR_WOMEN',
#   'WOMEN_PERF_FW',
#   'LDSRUNFW',
#   1122860,
#   '22Q1',
#   'Brooks Ghost 14 Womens Fw Black',
#   83,
#   10,
#   '12.05%',
#   '12,030',
#   '49.10%',
#   1143,
#   509,
#   13.77,
#   6.13),
#  ('FOOTWEAR_MEN',
#   'MEN_PERF_FW',
#   'MENSRUNFW',
#   1122887,
#   '22Q1',
#   'Brooks Adrenaline GTS 22 Mens Fw Navy',
#   79,
#   8,
#   '10.13%',
#   '11,438',
#   '49.00%',
#   1210,
#   503,
#   15.32,
#   6.37),
#  ('FOOTWEAR_WOMEN',
#   'WOMEN_PERF_FW',
#   'LDSRUNFW',
#   1122865,
#   '22Q1',
# ...
